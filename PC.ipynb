# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from collections import defaultdict
import time
import psycopg2
from user_agent import generate_user_agent
import numpy as np
import string

# %%
# %pdb off
# Out:
# Automatic pdb calling has been turned OFF

# %%
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
html = "https://forums.psychcentral.com/anxiety-panic-phobias/"

# %%
response = requests.get("https://forums.psychcentral.com/anxiety-panic-phobias/")

# %%
soup = BeautifulSoup(response.text, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-65765ea1af83> in <module>()
# ----> 1 soup = BeautifulSoup(response.text, "html.parser")
#
# NameError: name 'response' is not defined

# %%
from pc_scrape import *

# %%
# create db tables
create_db_tables()

# %%
parse_forum(html)
# Out:
# Jun 2010
# Aug 2012
# Oct 2014
# Feb 2013
# Sep 2015
# Oct 2010
# Dec 2017
# Jul 2015
# Jan 2018
# Dec 2014
# Apr 2017
# Jan 2018
# Mar 2017
# Jun 2013
# Apr 2015
# Aug 2017
# Mar 2017
# Dec 2015
# Sep 2014
# https://forums.psychcentral.com/anxiety-panic-phobias/501695-anxiety-daily-check-point-5-a-2.html
# Jan 2015
# Sep 2017
# Jan 2014
# https://forums.psychcentral.com/anxiety-panic-phobias/501695-anxiety-daily-check-point-5-a-3.html
# Dec 2017
# Aug 2016
# https://forums.psychcentral.com/anxiety-panic-phobias/501695-anxiety-daily-check-point-5-a-4.html
# Apr 2016
# nan
# Apr 2017
# https://forums.psychcentral.com/anxiety-panic-phobias/501695-anxiety-daily-check-point-5-a-5.html
# Dec 2017
# https://forums.psychcentral.com/anxiety-panic-phobias/501695-anxiety-daily-check-point-5-a-6.html
# Nov 2017
# https://forums.psychcentral.com/anxiety-panic-phobias/501695-anxiety-daily-check-point-5-a-7.html
# Nov 2016
# ...

# %%
# create threads
threads = parse_thread_page(soup)

# %%
from multiprocessing import Pool
p = Pool()

# %%
% time add_to_db(threads)
# Out:
# CPU times: user 29.9 s, sys: 596 ms, total: 30.5 s
# Wall time: 3min 59s

# %%
# %time p.map(add_to_db, threads)
# Out:
# CPU times: user 24.5 ms, sys: 8.73 ms, total: 33.2 ms
# Wall time: 27.2 s
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
response = get_request("https://forums.psychcentral.com/anxiety-panic-phobias/192066-scared-being-bad-person.html")

# %%
soup = soupify(response)

# %%
tables = get_tables(soup)

# %%
tables[6].find('div', {'class': 'smallfont'}).text
# Out:
# 'AdministratorCommunity Support Team'
